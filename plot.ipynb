# %%
import pandas as pd

# Read the data from the CSV file row by row
df = pd.read_csv('SPS_values_opt1_grid.csv', sep=',', header=None)

# %%
df_transposed = df.transpose()
df_transposed
# Out:
#                0
# 0    1881.147372
# 1    1725.135216
# 2    1575.321304
# 3    1403.708917
# 4    1279.854157
# ..           ...
# 995   853.074148
# 996   853.313467
# 997   853.544697
# 998   853.818171
# 999   853.935499
#
# [1000 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

# Plot the dataframe
plt.plot(df_transposed.index, df_transposed[0])
plt.xlabel('Number of Iterations')
plt.ylabel('SPS')
plt.title('Optimized Grid Values')
plt.grid(True)  # Add grid lines
# plt.xticks(range(0, 1000, 100))  # Set x-axis tick marks
plt.yticks(range(600, 1401, 100))  # Set y-axis tick marks
plt.tight_layout()  # Adjust the spacing
plt.show()

# %%
df2 = pd.read_csv('SPS_values_non_opt_grid.csv', sep=',', header=None)

# %%
df2_transposed = df2.transpose()

# %%
df2_transposed
# Out:
#                0
# 0    1851.234067
# 1    1514.312173
# 2    1421.501459
# 3    1360.825157
# 4    1122.406737
# ..           ...
# 995   687.495106
# 996   687.511876
# 997   687.413876
# 998   687.448916
# 999   687.387164
#
# [1000 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

# Plot the dataframe
plt.plot(df2_transposed.index, df2_transposed[0])
plt.xlabel('Number of Iterations')
plt.ylabel('SPS')
plt.title('Non_Optimized Grid Values')
plt.grid(True)  # Add grid lines
# plt.xticks(range(0, 1000, 100))  # Set x-axis tick marks
plt.yticks(range(600, 1401, 100))  # Set y-axis tick marks
plt.tight_layout()  # Adjust the spacing
plt.show()

# %%
df3 = pd.read_csv('SPS_values_opt2_grid.csv', sep=',', header=None)
df3_transposed = df3.transpose()
import matplotlib.pyplot as plt

# Plot the dataframe
plt.plot(df3_transposed.index, df3_transposed[0])
plt.xlabel('Number of Iterations')
plt.ylabel('SPS')
plt.title('Optimized_2 Grid Values')
plt.grid(True)  # Add grid lines
# plt.xticks(range(0, 1000, 100))  # Set x-axis tick marks
plt.yticks(range(600, 1401, 100))  # Set y-axis tick marks
plt.tight_layout()  # Adjust the spacing
plt.show()

# %%
df3 = pd.read_csv('SPS_values_opt3_grid.csv', sep=',', header=None)
df3_transposed = df3.transpose()
import matplotlib.pyplot as plt

# Plot the dataframe
plt.plot(df3_transposed.index, df3_transposed[0])
plt.xlabel('Number of Iterations')
plt.ylabel('SPS')
plt.title('Optimized_3 Grid Values')
plt.grid(True)  # Add grid lines
# plt.xticks(range(0, 1000, 100))  # Set x-axis tick marks
plt.yticks(range(600, 1401, 100))  # Set y-axis tick marks
plt.tight_layout()  # Adjust the spacing
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot the lines
plt.plot(df_transposed.index, df_transposed[0], label='Optimized_1, Precision=1')
# plt.plot(df_transposed.index, df3_transposed[0], label='Optimized_2, Precision=50')
plt.plot(df_transposed.index, df3_transposed[0], label='Optimized_3, Precision=100')

plt.plot(df2_transposed.index, df2_transposed[0], label='Non-Optimized')

# Set labels and title
plt.xlabel('Number of Iterations [Averaged across 1000 steps for each iteration]')
plt.ylabel('SPS')
plt.title('Comparison of Optimized with different precisions and Non-Optimized in Grid Observation')

# Add legend
plt.legend()

# Set y-axis limits
plt.ylim(600, 2000)

# Show the plot
plt.show()

# %%
import pandas as pd

# Read the data from the CSV file row by row
df_s = pd.read_csv('SPS_values_not_opt_screen.csv', sep=',', header=None)
df_s_transposed = df_s.transpose()

#Plot the dataframe

import matplotlib.pyplot as plt

# Plot the dataframe
plt.plot(df_s_transposed.index, df_s_transposed[0])
plt.xlabel('Number of Iterations')
plt.ylabel('SPS')
plt.title('Non_Optimized Screen Values')
plt.grid(True)  # Add grid lines
# plt.xticks(range(0, 1000, 100))  # Set x-axis tick marks
plt.yticks(range(100, 801, 100))  # Set y-axis tick marks
plt.tight_layout()  # Adjust the spacing
plt.show()

# %%
import pandas as pd

# Read the data from the CSV file row by row
df_s_2 = pd.read_csv('SPS_values_opt_screen.csv', sep=',', header=None)
df_s__2_transposed = df_s_2.transpose()

#Plot the dataframe

import matplotlib.pyplot as plt

# Plot the dataframe
plt.plot(df_s__2_transposed.index, df_s__2_transposed[0])
plt.xlabel('Number of Iterations')
plt.ylabel('SPS')
plt.title('Non_Optimized Screen Values')
plt.grid(True)  # Add grid lines
# plt.xticks(range(0, 1000, 100))  # Set x-axis tick marks
plt.yticks(range(100, 801, 100))  # Set y-axis tick marks
plt.tight_layout()  # Adjust the spacing
plt.show()

# %%
import pandas as pd

# Read the data from the CSV file row by row
df_s_3 = pd.read_csv('SPS_values_opt2_screen.csv', sep=',', header=None)
df_s_3_transposed = df_s_3.transpose()

#Plot the dataframe

import matplotlib.pyplot as plt

# Plot the dataframe
plt.plot(df_s_3_transposed.index, df_s_3_transposed[0])
plt.xlabel('Number of Iterations')
plt.ylabel('SPS')
plt.title('Optimized Screen Values')
plt.grid(True)  # Add grid lines
# plt.xticks(range(0, 1000, 100))  # Set x-axis tick marks
plt.yticks(range(100, 801, 100))  # Set y-axis tick marks
plt.tight_layout()  # Adjust the spacing
plt.show()

# %%
import pandas as pd

# Read the data from the CSV file row by row
df_s_2 = pd.read_csv('SPS_values_opt3_screen.csv', sep=',', header=None)
df_s__2_transposed = df_s_2.transpose()

#Plot the dataframe

import matplotlib.pyplot as plt

# Plot the dataframe
plt.plot(df_s__2_transposed.index, df_s__2_transposed[0])
plt.xlabel('Number of Iterations')
plt.ylabel('SPS')
plt.title('Non_Optimized Screen Values')
plt.grid(True)  # Add grid lines
# plt.xticks(range(0, 1000, 100))  # Set x-axis tick marks
plt.yticks(range(100, 801, 100))  # Set y-axis tick marks
plt.tight_layout()  # Adjust the spacing
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot the lines
plt.plot(df_s_transposed.index, df_s_transposed[0], label='Non-Optimized')
plt.plot(df_s__2_transposed.index, df_s__2_transposed[0], label='Optimized, Precision=1')
plt.plot(df_s_3_transposed.index, df_s_3_transposed[0], label='Optimized_2, Precision=50')
# Set labels and title
plt.xlabel('Number of Iterations [Averaged across 1000 steps for each iteration]')
plt.ylabel('SPS')
plt.title('Comparison of Optimized and Non-Optimized in Screen Observation')

# Add legend
plt.legend()

# Set y-axis limits
plt.ylim(0, 1000)

# Show the plot
plt.show()
